# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-MinesData/Tourism-Data-Story-Top-Cities/blob/main/Tourism_Data_Story_Top_Cities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install folium pandas

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd
from branca.colormap import LinearColormap

# %%
# Sample data (replace this with actual data)
data = {
    'City': ['Paris', 'Bangkok', 'London', 'Dubai', 'Singapore',
             'New York', 'Kuala Lumpur', 'Tokyo', 'Istanbul', 'Seoul',
             'Hong Kong', 'Mumbai', 'Rome', 'Osaka', 'Taipei',
             'Mecca', 'Pattaya', 'Phuket', 'Guangzhou', 'Miami',
             'Barcelona', 'Moscow', 'Prague', 'Amsterdam', 'Vienna'],
    'Rank': list(range(1, 26)),
    'Visitors': [85.0, 76.3, 72.0, 68.0, 66.7,
                  65.2, 63.5, 62.3, 60.1, 59.3,
                  58.7, 57.0, 56.4, 55.8, 54.2,
                  53.9, 52.8, 51.7, 50.6, 49.5,
                  48.4, 47.3, 46.2, 45.1, 44.0],  # In millions
    'Latitude': [48.8566, 13.7563, 51.5074, 25.2769, 1.3521,
                 40.7128, 3.1390, 35.6762, 41.0082, 37.5665,
                 22.3193, 19.0760, 41.9028, 34.6937, 25.0330,
                 21.3891, 12.9236, 7.9519, 23.1291, 25.7617,
                 41.3851, 55.7558, 50.0755, 52.3676, 48.2082],
    'Longitude': [2.3522, 100.5018, -0.1278, 55.2962, 103.8198,
                  -74.0060, 101.6869, 139.6503, 28.9784, 126.9780,
                  114.1694, 72.8777, 12.4964, 135.5023, 121.5654,
                  39.8579, 100.8824, 98.3381, 113.2644, -80.1918,
                  2.1734, 37.6173, 14.4378, 4.9041, 16.3738]
}

df = pd.DataFrame(data)

# %%
# Create color scale
colormap = LinearColormap(
    colors=['green', 'yellow', 'red'],
    vmin=df['Visitors'].min(),
    vmax=df['Visitors'].max()
)

# %%
# Create base map
m = folium.Map(location=[20, 0], zoom_start=2, tiles='cartodbpositron')

# Add marker cluster
marker_cluster = MarkerCluster().add_to(m)

# %%
# Add points to the map
for idx, row in df.iterrows():
    popup_text = f"""
    City: {row['City']}<br>
    Rank: {row['Rank']}<br>
    Visitors: {row['Visitors']}M
    """
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=10,
        popup=popup_text,
        color=colormap(row['Visitors']),
        fill=True,
        fill_color=colormap(row['Visitors']),
        fill_opacity=0.7,
        weight=1
    ).add_to(marker_cluster)

# %%
# Add color scale legend
colormap.caption = 'Number of Visitors (Millions)'
colormap.add_to(m)
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#008000ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#018100ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#028100ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#038200ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#048200ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#058300ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#068300ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#078400ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#098500ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#0a8500ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#0b8600ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#0c8600ff;stroke-width:2;" /><line x1="12" y1=
# ...

# %%
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
